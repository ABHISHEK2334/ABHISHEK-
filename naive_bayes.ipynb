# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHISHEK2334/ABHISHEK-/blob/main/naive_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.metrics import accuracy_score

# %%
path="/content/titanic.csv"
df=pd.read_csv(path,usecols=['Pclass','Sex','Age','Fare','Survived'])
df.head()
# Out:
#    Pclass     Sex   Age     Fare  Survived
# 0       3    male  22.0   7.2500         0
# 1       1  female  38.0  71.2833         1
# 2       3  female  26.0   7.9250         1
# 3       1  female  35.0  53.1000         1
# 4       3    male  35.0   8.0500         0

# %%
x=df.drop("Survived",axis='columns')
y=df["Survived"]

# %%
ohe=pd.get_dummies(x['Sex']).astype(int)
x=pd.concat([x,ohe],axis="columns")
x.drop(['Sex'],axis='columns',inplace=True)
x
# Out:
#      Pclass   Age     Fare  female  male
# 0         3  22.0   7.2500       0     1
# 1         1  38.0  71.2833       1     0
# 2         3  26.0   7.9250       1     0
# 3         1  35.0  53.1000       1     0
# 4         3  35.0   8.0500       0     1
# ..      ...   ...      ...     ...   ...
# 886       2  27.0  13.0000       0     1
# 887       1  19.0  30.0000       1     0
# 888       3   NaN  23.4500       1     0
# 889       1  26.0  30.0000       0     1
# 890       3  32.0   7.7500       0     1
#
# [891 rows x 5 columns]

# %%
x.isnull().sum()
#x.columns[x.isna().any()]
x['Age'].fillna(x['Age'].mean(),inplace=True)

# %%
x.isnull().sum()
# Out:
# Pclass    0
# Age       0
# Fare      0
# female    0
# male      0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()

# %%
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(x_test)
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.7761194029850746

# %%
model.score(x_test,y_test)
# Out:
# 0.7761194029850746
