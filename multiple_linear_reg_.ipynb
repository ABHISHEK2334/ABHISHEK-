# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHISHEK2334/ABHISHEK-/blob/main/multiple_linear_reg_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import plotly.express as px
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
path="/content/Walmart_sales.csv"
df=pd.read_csv(path,usecols=["Weekly_Sales","Fuel_Price","CPI"])
df.head()
# Out:
#    Weekly_Sales  Fuel_Price         CPI
# 0    1643690.90       2.572  211.096358
# 1    1641957.44       2.548  211.242170
# 2    1611968.17       2.514  211.289143
# 3    1409727.59       2.561  211.319643
# 4    1554806.68       2.625  211.350143

# %%
df.shape
# Out:
# (6435, 3)

# %%
px.scatter_3d(df,x="Weekly_Sales",y="Fuel_Price",z="CPI")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
ir=LinearRegression()

# %%
ir.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=ir.predict(x_test)

# %%
print("MAE=", mean_absolute_error(y_test,y_pred))
print("MSE=", mean_squared_error(y_test,y_pred))
print("R2_SCORE=", r2_score(y_test,y_pred))
# Out:
# MAE= 37.329213999084374
# MSE= 1564.9995544056258
# R2_SCORE= 0.0170682413416976

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df["Weekly_Sales"], df["Fuel_Price"], df["CPI"], color='r', marker='o', label='Data Points')

# Plot the regression plane
x_range = np.linspace(df["Weekly_Sales"].min(), df["Weekly_Sales"].max(), 10)
y_range = np.linspace(df["Fuel_Price"].min(), df["Fuel_Price"].max(), 10)
X_range, Y_range = np.meshgrid(x_range, y_range)
Z_range = lr.predict(np.c_[X_range.ravel(), Y_range.ravel()]).reshape(X_range.shape)
ax.plot_surface(X_range, Y_range, Z_range, alpha=0.5, label='Regression Plane')


ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('Y')

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
